# %%
# !nvidia-smi
# Out:
# Thu Mar 23 14:32:45 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 451.67       Driver Version: 451.67       CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1050   WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   49C    P8    N/A /  N/A |     76MiB /  3072MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %pip install -qr requirements.txt --user
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Python311\Lib\site-packages\folium-0.0.0-py3.11.egg\EGG-INFO due to invalid metadata entry 'name'
# WARNING: Skipping c:\Python311\Lib\site-packages\folium-0.0.0-py3.11.egg\EGG-INFO due to invalid metadata entry 'name'

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.54  Python-3.11.0 torch-2.0.0+cpu CPU
# Setup complete  (8 CPUs, 15.8 GB RAM, 68.4/126.2 GB disk)

# %%
from ultralytics import YOLO
 
model = YOLO('yolov8n.yaml').load('yolov8n.pt')
model.train(data='Letter_detect.yaml', epochs=30, imgsz=640, batch=32, cache=True)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    897664  ultralytics.nn.modules.Detect                [80, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3157200 parameters, 3157184 gradients, 8.9 GFLOPs
#
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 12.8MB/s]
# Transferred 355/355 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.0.55 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.54  Python-3.11.0 torch-2.0.0+cpu CPU
# yolo\engine\trainer: task=detect, mode=train, model=C:\Python311\Lib\site-packages\ultralytics\models\v8\yolov8n.yaml, data=Letter_detect.yaml, epochs=30, patience=50, batch=32, imgsz=640, save=True, save_period=-1, cache=True, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs\detect\train
# Overriding model.yaml nc=80 with nc=30
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    757162  ultralytics.nn.modules.Detect                [30, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3016698 parameters, 3016682 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# 2023-03-23 14:34:02,755 - clearml.Repository Detection - WARNING - Could not read Jupyter Notebook: No module named 'nbconvert'
# WARNING  ClearML installed but not initialized correctly, not logging this run. It seems ClearML is not configured on this machine!
# To get started with ClearML, setup your own 'clearml-server' or create a free account at https://app.clear.ml
# Setup instructions can be found here: https://clear.ml/docs
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias
# train: Scanning D:\TIPA\License\Yolov8_ver1\training\OCR\train\labels... 3054 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3054/3054 [00:01<00:00, 2561.77it/s]
# train: WARNING  D:\TIPA\License\Yolov8_ver1\training\OCR\train\images\ndata148_jpg.rf.1e11f0fc5337745ebcd3a76a4e632b3f.jpg: 1 duplicate labels removed
# train: WARNING  D:\TIPA\License\Yolov8_ver1\training\OCR\train\images\ndata301_jpg.rf.eaedb1e8460457c848f47b98dd403fef.jpg: 1 duplicate labels removed
# train: New cache created: D:\TIPA\License\Yolov8_ver1\training\OCR\train\labels.cache
# train: Caching images (3.8GB True): 100%|██████████| 3054/3054 [00:03<00:00, 828.04it/s]
# val: Scanning D:\TIPA\License\Yolov8_ver1\training\OCR\valid\labels... 765 images, 0 backgrounds, 0 corrupt: 100%|██████████| 765/765 [00:00<00:00, 2514.54it/s]
# val: New cache created: D:\TIPA\License\Yolov8_ver1\training\OCR\valid\labels.cache
# val: Caching images (0.9GB True): 100%|██████████| 765/765 [00:00<00:00, 817.22it/s]
# Plotting labels to runs\detect\train\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\train
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30         0G      1.204      3.469      1.223        166        640: 100%|██████████| 96/96 [23:47<00:00, 14.87s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [02:18<00:00, 11.56s/it]
#                    all        765       6236      0.939      0.121      0.275      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30         0G      1.126      1.625      1.193        198        640: 100%|██████████| 96/96 [21:40<00:00, 13.55s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [02:14<00:00, 11.20s/it]
#                    all        765       6236      0.644      0.449      0.456      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30         0G       1.14      1.253      1.189        209        640: 100%|██████████| 96/96 [1:35:26<00:00, 59.66s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [02:15<00:00, 11.32s/it]
#                    all        765       6236      0.699      0.673      0.755      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30         0G      1.114      1.116      1.184        155        640: 100%|██████████| 96/96 [21:55<00:00, 13.71s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 
0.746
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30         0G     0.8728     0.4404      1.145        107        640: 100%|██████████| 96/96 [40:52<00:00, 25.54s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [02:16<00:00, 11.36s/it]
#                    all        765       6236      0.974      0.961      0.981      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30         0G     0.8678     0.4346       1.14        112        640: 100%|██████████| 96/96 [21:31<00:00, 13.45s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [02:14<00:00, 11.20s/it]
#                    all        765       6236      0.967      0.967      0.983      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30         0G     0.8656     0.4244      1.136        114        640: 100%|██████████| 96/96 [2:57:12<00:00, 110.75s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [02:28<00:00, 12.34s/it]
#                    all        765       6236      0.976      0.969      0.983      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30         0G      0.862     0.4182      1.136        109        640: 100%|██████████| 96/96 [25:15<00:00, 15.78s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [02:44<00:00, 13.74s/it]
#                    all        765       6236      0.966      0.973      0.979      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30         0G     0.8499     0.4047      1.127        112        640: 100%|██████████| 96/96 [26:02<00:00, 16.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [02:51<00:00, 14.29s/it]
#                    all        765       6236      0.974      0.968      0.984      0.758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30         0G     0.8443     0.3967      1.127        116        640: 100%|██████████| 96/96 [22:13<00:00, 13.89s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [02:17<00:00, 11.47s/it]
#                    all        765       6236      0.977      0.971      0.981      0.758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30         0G     0.8414     0.3938       1.12        112        640: 100%|██████████| 96/96 [25:52<00:00, 16.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [02:48<00:00, 14.06s/it]
#                    all        765       6236      0.976      0.976       0.98      0.758
#
# 30 epochs completed in 32.710 hours.
# Optimizer stripped from runs\detect\train\weights\last.pt, 6.3MB
# Optimizer stripped from runs\detect\train\weights\best.pt, 6.3MB
#
# Validating runs\detect\train\weights\best.pt...
# Ultralytics YOLOv8.0.54  Python-3.11.0 torch-2.0.0+cpu CPU
# YOLOv8n summary (fused): 168 layers, 3011498 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [02:10<00:00, 10.88s/it]
#                    all        765       6236      0.974      0.968      0.984      0.758
#                      0        765        461      0.986      0.996      0.991      0.801
#                      1        765        836      0.989      0.978      0.983      0.682
#                      2        765        541      0.996      0.984      0.994      0.801
#                      3        765        423      0.995      0.986      0.994      0.794
#                      4        765        425      0.988      0.991      0.993      0.761
#                      5        765        754      0.989      0.989      0.993      0.792
#                      6        765        428       0.99      0.991      0.993      0.786
#                      7        765        418      0.986      0.988      0.993      0.773
#                      8        765        373      0.981      0.979       0.99      0.769
#                      9        765        630      0.994      0.989      0.993      0.797
#                      A        765         64          1      0.984      0.993      0.738
#                      B        765        153       0.98      0.945      0.986      0.787
#                      C        765         52          1      0.931      0.969      0.739
#                      D        765         56      0.893      0.891      0.923      0.703
#                      E        765         40      0.981          1      0.995      0.826
#                      F        765         72      0.996          1      0.995      0.761
#                      G        765         68      0.986      0.956      0.984      0.679
#                      H        765         39          1      0.893      0.977      0.794
#                      K        765         34      0.997      0.971      0.993      0.718
#                      L        765         42       0.98      0.976      0.995      0.733
#                      M        765         60      0.905      0.956      0.971       0.77
#                      N        765         22       0.93      0.909      0.958      0.747
#                      P        765         34      0.989          1      0.995      0.759
#                      S        765         40       0.99          1      0.995      0.753
#                      T        765         33      0.973          1      0.995      0.765
#                      U        765         31      0.968      0.982       0.99      0.746
#                      V        765         17      0.924      0.941      0.973      0.739
#                      X        765         26          1      0.976      0.995      0.746
#                      Y        765          9      0.857      0.889      0.923      0.741
#                      Z        765         55      0.988      0.982      0.995      0.745
# Speed: 2.0ms preprocess, 160.8ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs\detect\train

# %% [markdown]
# **Train YOLOv8 vid CLI**<br>
# *!yolo detect train data=Letter_detect.yaml model=yolov8n.yaml pretrained=yolov8n.pt imgsz=640 batch=32 epochs=30 cache=True*
